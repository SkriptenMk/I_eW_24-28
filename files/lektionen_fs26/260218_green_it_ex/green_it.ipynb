# %% [markdown]
# # Green IT Data Viz Project

# %% [markdown]
# In class the environmental footprint of IT was discussed. There were two
# key takeaways:
#
# * Data centers are responsible for about 1.5% of the global electric
#   power consumption.
# * Energy efficiency is measured as Power Usage Effectiveness.
#
#   ($\text{PUE}=\frac{total\ power\ consumption\ dc}{power\ consumption\ IT}$)

# %% [markdown]
# In this exercise book there are the to calculate PUEs of given companys
# and to visualize (and interprete) E-waste data.

# %% [markdown]
# ## Exercise PUE

# %%
# --- Setup (do not modify) ---
import pandas as pd
import matplotlib.pyplot as plt

# --- Data: PUE values of major cloud providers ---
# Sources: see reference table below
data_centers = {
    "Name": [
        "Google (global, 2024)",
        "AWS (global, 2024)",
        "Microsoft (global, 2022)",
        "Meta (Luleå, 2024)",
        "Branchendurchschnitt (2024)"
    ],
    "PUE": [
        1.09,   # Google Environmental Report 2025
        1.15,   # AWS Sustainability Report 2024
        1.18,   # Microsoft Azure Blog (2022)
        1.07,   # Meta/DCPulse (Luleå, Schweden)
        1.56    # Uptime Institute Survey 2024
    ]
}
df_dc = pd.DataFrame(data_centers)

# TODO 1: Create a horizontal bar chart (barh)
# of the PUE values for all data centers.
# Draw a vertical line at PUE = 1.0
# (theoretical optimum).
# Color the bars by efficiency:
#   green (< 1.2), orange (1.2–1.4), red (> 1.4).

# %% [markdown]
# ## Exercise E-Waste

# %%
# --- Data: Global e-waste ---
# Source: Global E-Waste Monitor 2024
# (UNITAR/ITU), including projections
data_ewaste = {
    "Jahr": [
        2010, 2014, 2019, 2022, 2030
    ],
    "E_Waste_Mio_t": [
        34.0, 41.8, 53.6, 62.0, 82.0
    ],
    "Recycelt_Prozent": [
        23.5, 22.5, 17.4, 22.3, 20.0
    ]
}
df_ew = pd.DataFrame(data_ewaste)

# TODO 2: Create a line chart with two y-axes:
# E-Waste (million tonnes) on the left and
# recycling rate (%) on the right, over time.
# Mark 2030 as "Projection".
# Label the axes appropriately.


# TODO 3: Calculate how many million tonnes of
# e-waste were NOT recycled in 2022.
# Calculate the value of unrecycled raw
# materials (according to UNITAR: USD 62 bn
# at a 22.3% recycling rate).
# Print the result using print().
